# %% [markdown]
# # Boundary from Children Demo
#
# This notebook tests and visualizes the `cell_boundary_from_children` function which computes a cell's boundary using its descendant cells at a finer resolution.

# %%
import h3
import folium
from h3_toolkit.utils import children_on_boundary_faces
from h3_toolkit.geom import cell_boundary_to_geojson, cell_boundary_from_children

print("Imports successful!")
# Out:
# Imports successful!

# %% [markdown]
# ## 1. Basic Test
#
# Pick a parent cell and compute its boundary from children at different resolutions.

# %%
# Create a parent cell at resolution 6
# Res 8 parent with C++ bindings is fast!
lat, lng, res = 37.7749, -122.4194, 8
parent = h3.latlng_to_cell(lat, lng, res)
print(f"Parent cell: {parent}")
print(f"Parent resolution: {h3.get_resolution(parent)}")

# Get boundary children at res 8
child_res =14
boundary_children = children_on_boundary_faces(parent, child_res)
print(f"\nBoundary children at res {child_res}: {len(boundary_children)}")

# Get merged boundary GeoJSON
boundary_geojson = cell_boundary_from_children(parent, child_res)
print(f"\nGeoJSON properties: {boundary_geojson['properties']}")
# Out:
# Parent cell: 8828308281fffff
# Parent resolution: 8
#
# Boundary children at res 14: 2184
#
# GeoJSON properties: {'h3_index': '8828308281fffff', 'child_resolution': 14, 'num_boundary_cells': 2184}

# %% [markdown]
# ## 2. Visualization: Compare Smooth vs Jagged Boundary

# %%
m = folium.Map(location=[lat, lng], zoom_start=13)

# Original smooth boundary (red dashed)
smooth_boundary = cell_boundary_to_geojson(parent)
folium.GeoJson(
    smooth_boundary,
    style_function=lambda x: {
        'color': 'red', 
        'fillOpacity': 0, 
        'weight': 4, 
        'dashArray': '10,5'
    },
    name='Smooth Boundary'
).add_to(m)

# Boundary from children (blue solid)
folium.GeoJson(
    boundary_geojson,
    style_function=lambda x: {
        'color': 'blue', 
        'fillOpacity': 0.15, 
        'weight': 2
    },
    name='Boundary from Children'
).add_to(m)

# Add layer control
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f177989c0fcc4c871fef701fcced306 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f177989c0fcc4c871fef701fcced306&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f177989c0fcc4c871fef701fcced306 = L.map(
#                 &quot;map_9f177989c0fcc4c871fef701fcced306&quot;,
#                 {
#                     center: [37.7749, -122.4194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7edfffca5763bffb841c02b3302b4ce9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7edfffca5763bffb841c02b3302b4ce9.addTo(map_9f177989c0fcc4c871fef701fcced306);
#
#
#         function geo_json_fe280dade4baeba53dc73450c19c77ba_styler(feature) {
#             switch(feature.properties.h3_index) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: &quot;10,5&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 4};
#             }
#         }
#
#         function geo_json_fe280dade4baeba53dc73450c19c77ba_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_fe280dade4baeba53dc73450c19c77ba = L.geoJson(null, {
#                 onEachFeature: geo_json_fe280dade4baeba53dc73450c19c77ba_onEachFeature,
#
#                 style: geo_json_fe280dade4baeba53dc73450c19c77ba_styler,
#             ...{
# }
#         });
#
#         function geo_json_fe280dade4baeba53dc73450c19c77ba_add (data) {
#             geo_json_fe280dade4baeba53dc73450c19c77ba
#                 .addData(data);
#         }
#             geo_json_fe280dade4baeba53dc73450c19c77ba_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.416823, 37.768823], [-122.41235, 37.772367], [-122.413797, 37.777059], [-122.419719, 37.778207], [-122.424192, 37.774663], [-122.422744, 37.769972], [-122.416823, 37.768823]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;h3_index&quot;: &quot;8828308281fffff&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_fe280dade4baeba53dc73450c19c77ba.addTo(map_9f177989c0fcc4c871fef701fcced306);
#
#
#         function geo_json_8728bb11410c49d3efc1303f06bde96b_styler(feature) {
#             switch(feature.properties.h3_index) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.15, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_8728bb11410c49d3efc1303f06bde96b_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_8728bb11410c49d3efc1303f06bde96b = L.geoJson(null, {
#                 onEachFeature: geo_json_8728bb11410c49d3efc1303f06bde96b_onEachFeature,
#
#                 style: geo_json_8728bb11410c49d3efc1303f06bde96b_styler,
#             ...{
# }
#         });
#
#         function geo_json_8728bb11410c49d3efc1303f06bde96b_add (data) {
#             geo_json_8728bb11410c49d3efc1303f06bde96b
#                 .addData(data);
#         }
#             geo_json_8728bb11410c49d3efc1303f06bde96b_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.423801, 37.770871], [-122.423805, 37.770885], [-122.423822, 37.770888], [-122.423827, 37.770902], [-122.423844, 37.770905], [-122.423857, 37.770895], [-122.423874, 37.770898], [-122.423878, 37.770912], [-122.423896, 37.770915], [-122.4239, 37.770929], [-122.423917, 37.770932], [-122.42393, 37.770922], [-122.423947, 37.770925], [-122.423952, 37.770939], [-122.423969, 37.770942], [-122.423973, 37.770956], [-122.42396, 37.770966], [-122.423964, 37.77098], [-122.423951, 37.77099], [-122.423955, 37.771004], [-122.423973, 37.771007], [-122.423977, 37.771021], [-122.423964, 37.771031], [-122.423968, 37.771045], [-122.423955, 37.771055], [-122.423938, 37.771052], [-122.423925, 37.771062], [-122.423908, 37.771059], [-122.423894, 37.771069], [-122.423899, 37.771083], [-122.423886, 37.771093], [-122.42389, 37.771107], [-122.423907, 37.77111], [-122.423911, 37.771124], [-122.423898, 37.771134], [-122.423903, 37.771148], [-122.42389, 37.771158], [-122.423894, 37.771172], [-122.423911, 37.771175], [-122.423915, 37.771189], [-122.423902, 37.771199], [-122.423906, 37.771213], [-122.423893, 37.771223], [-122.423876, 37.77122], [-122.423863, 37.77123], [-122.423846, 37.771227], [-122.423833, 37.771237], [-122.423837, 37.771251], [-122.423824, 37.771261], [-122.423828, 37.771

# %% [markdown]
# ## 3. Show Individual Boundary Children

# %%
m2 = folium.Map(location=[37.775938728915946, -122.41795063018799], zoom_start=13)

# Parent boundary
folium.GeoJson(
    smooth_boundary,
    style_function=lambda x: {'color': 'red', 'fillOpacity': 0, 'weight': 3, 'dashArray': '5,5'}
).add_to(m2)

# Each boundary child
for child in boundary_children:
    child_geojson = cell_boundary_to_geojson(child)
    folium.GeoJson(
        child_geojson,
        style_function=lambda x: {'color': 'purple', 'fillOpacity': 0.3, 'weight': 1}
    ).add_to(m2)

m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce93855aa03fc662454389b4f51aefe8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce93855aa03fc662454389b4f51aefe8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce93855aa03fc662454389b4f51aefe8 = L.map(
#                 &quot;map_ce93855aa03fc662454389b4f51aefe8&quot;,
#                 {
#                     center: [37.775938728915946, -122.41795063018799],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9d83c2fdb15050e77274f0b1771460b9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9d83c2fdb15050e77274f0b1771460b9.addTo(map_ce93855aa03fc662454389b4f51aefe8);
#
#
#         function geo_json_7820baab2c7d27a1f45823455c9be567_styler(feature) {
#             switch(feature.properties.h3_index) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: &quot;5,5&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_7820baab2c7d27a1f45823455c9be567_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_7820baab2c7d27a1f45823455c9be567 = L.geoJson(null, {
#                 onEachFeature: geo_json_7820baab2c7d27a1f45823455c9be567_onEachFeature,
#
#                 style: geo_json_7820baab2c7d27a1f45823455c9be567_styler,
#             ...{
# }
#         });
#
#         function geo_json_7820baab2c7d27a1f45823455c9be567_add (data) {
#             geo_json_7820baab2c7d27a1f45823455c9be567
#                 .addData(data);
#         }
#             geo_json_7820baab2c7d27a1f45823455c9be567_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.408139, 37.740666], [-122.376819, 37.765468], [-122.386946, 37.798315], [-122.428409, 37.806353], [-122.459718, 37.781545], [-122.449575, 37.748707], [-122.408139, 37.740666]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;h3_index&quot;: &quot;86283082fffffff&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_7820baab2c7d27a1f45823455c9be567.addTo(map_ce93855aa03fc662454389b4f51aefe8);
#
#
#         function geo_json_d2bd18e590eccf8ae8bbc50f3d2f6ca6_styler(feature) {
#             switch(feature.properties.h3_index) {
#                 default:
#                     return {&quot;color&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_d2bd18e590eccf8ae8bbc50f3d2f6ca6_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_d2bd18e590eccf8ae8bbc50f3d2f6ca6 = L.geoJson(null, {
#                 onEachFeature: geo_json_d2bd18e590eccf8ae8bbc50f3d2f6ca6_onEachFeature,
#
#                 style: geo_json_d2bd18e590eccf8ae8bbc50f3d2f6ca6_styler,
#             ...{
# }
#         });
#
#         function geo_json_d2bd18e590eccf8ae8bbc50f3d2f6ca6_add (data) {
#             geo_json_d2bd18e590eccf8ae8bbc50f3d2f6ca6
#                 .addData(data);
#         }
#             geo_json_d2bd18e590eccf8ae8bbc50f3d2f6ca6_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.449326, 37.783943], [-122.444853, 37.787488], [-122.446302, 37.792178], [-122.452224, 37.793324], [-122.456696, 37.78978], [-122.455247, 37.78509], [-122.449326, 37.783943]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;h3_index&quot;: &quot;8828308293fffff&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_d2bd18e590eccf8ae8bbc50f3d2f6ca6.addTo(map_ce93855aa03fc662454389b4f51aefe8);
#
#
#         function geo_json_0351269ad7e8211bf963e89497cbfcaa_styler(feature) {
#             switch(feature.properties.h3_index) {
#                 default:
#                     return {&quot;color&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_0351269ad7e8211bf963e89497cbfcaa_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_0351269ad7e8211bf963e89497cbfcaa = L.geoJson(null, {
#                 onEachFeature: geo_json_0351269ad7e8211bf963e89497cbfcaa_onEachFeature,
#
#                 style: geo_json_0351269ad7e8211bf963e89497cbfcaa_styler,
#             ...{
# }
#         });
#
#         function geo_j

# %% [markdown]
# ## 4. Different Resolutions Comparison

# %%
# Compare boundaries at different child resolutions
resolutions = [7, 8, 9]
colors = ['green', 'blue', 'orange']

m3 = folium.Map(location=[37.775938728915946, -122.41795063018799], zoom_start=13)

# Parent boundary
folium.GeoJson(
    smooth_boundary,
    style_function=lambda x: {'color': 'red', 'fillOpacity': 0, 'weight': 4, 'dashArray': '10,5'},
    name='Parent (smooth)'
).add_to(m3)

for res, color in zip(resolutions, colors):
    boundary = cell_boundary_from_children(parent, res)
    folium.GeoJson(
        boundary,
        style_function=lambda x, c=color: {'color': c, 'fillOpacity': 0.05, 'weight': 2},
        name=f'Res {res} ({boundary["properties"]["num_boundary_cells"]} cells)'
    ).add_to(m3)

folium.LayerControl().add_to(m3)
m3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2d4b61954d07bba0bbd99762f30280b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2d4b61954d07bba0bbd99762f30280b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a2d4b61954d07bba0bbd99762f30280b = L.map(
#                 &quot;map_a2d4b61954d07bba0bbd99762f30280b&quot;,
#                 {
#                     center: [37.775938728915946, -122.41795063018799],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15df1d661188e1a0c73d672a0caa3ab6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_15df1d661188e1a0c73d672a0caa3ab6.addTo(map_a2d4b61954d07bba0bbd99762f30280b);
#
#
#         function geo_json_1117b10095e02242b71bef8ef5e9a2fb_styler(feature) {
#             switch(feature.properties.h3_index) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: &quot;10,5&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 4};
#             }
#         }
#
#         function geo_json_1117b10095e02242b71bef8ef5e9a2fb_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_1117b10095e02242b71bef8ef5e9a2fb = L.geoJson(null, {
#                 onEachFeature: geo_json_1117b10095e02242b71bef8ef5e9a2fb_onEachFeature,
#
#                 style: geo_json_1117b10095e02242b71bef8ef5e9a2fb_styler,
#             ...{
# }
#         });
#
#         function geo_json_1117b10095e02242b71bef8ef5e9a2fb_add (data) {
#             geo_json_1117b10095e02242b71bef8ef5e9a2fb
#                 .addData(data);
#         }
#             geo_json_1117b10095e02242b71bef8ef5e9a2fb_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.408139, 37.740666], [-122.376819, 37.765468], [-122.386946, 37.798315], [-122.428409, 37.806353], [-122.459718, 37.781545], [-122.449575, 37.748707], [-122.408139, 37.740666]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;h3_index&quot;: &quot;86283082fffffff&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_1117b10095e02242b71bef8ef5e9a2fb.addTo(map_a2d4b61954d07bba0bbd99762f30280b);
#
#
#         function geo_json_2cdcf4b0b38c1f3b87635e985c494ee8_styler(feature) {
#             switch(feature.properties.h3_index) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.05, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_2cdcf4b0b38c1f3b87635e985c494ee8_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_2cdcf4b0b38c1f3b87635e985c494ee8 = L.geoJson(null, {
#                 onEachFeature: geo_json_2cdcf4b0b38c1f3b87635e985c494ee8_onEachFeature,
#
#                 style: geo_json_2cdcf4b0b38c1f3b87635e985c494ee8_styler,
#             ...{
# }
#         });
#
#         function geo_json_2cdcf4b0b38c1f3b87635e985c494ee8_add (data) {
#             geo_json_2cdcf4b0b38c1f3b87635e985c494ee8
#                 .addData(data);
#         }
#             geo_json_2cdcf4b0b38c1f3b87635e985c494ee8_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.42445, 37.739421], [-122.433265, 37.749955], [-122.449575, 37.748707], [-122.458392, 37.759237], [-122.450899, 37.771017], [-122.459718, 37.781545], [-122.452224, 37.793324], [-122.435908, 37.794575], [-122.428409, 37.806353], [-122.412088, 37.807601], [-122.403269, 37.797071], [-122.386946, 37.798315], [-122.378129, 37.787782], [-122.385635, 37.776004], [-122.376819, 37.765468], [-122.384324, 37.753689], [-122.40064, 37.752446], [-122.408139, 37.740666], [-122.42445, 37.739421]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;child_resolution&quot;: 7, &quot;h3_index&quot;: &quot;86283082fffffff&quot;, &quot;num_boundary_cells&quot;: 6}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_2cdcf4b0b38c1f3b87635e985c494ee8.addTo(map_a2d4b61954d07bba0bbd99762f30280b);
#
#
#         function geo_json_79ed6044384f5236f7c5fad21ab7bd02_styler(feature) {
#             switch(feature.properties.h3_index) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.05, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_79ed6044384f5236f7c5fad21ab7bd02_onEach

# %% [markdown]
# ## 5. Count Boundary Cells at Different Resolutions

# %%
print(f"Parent cell: {parent} (res {h3.get_resolution(parent)})")
print("\nBoundary children count by resolution:")
print("-" * 40)

for res in range(h3.get_resolution(parent) + 1, 11):
    children = children_on_boundary_faces(parent, res)
    print(f"Resolution {res}: {len(children):,} boundary cells")
# Out:
# Parent cell: 86283082fffffff (res 6)
#
# Boundary children count by resolution:
# ----------------------------------------
# Resolution 7: 6 boundary cells
# Resolution 8: 24 boundary cells
# Resolution 9: 78 boundary cells
# Resolution 10: 240 boundary cells
